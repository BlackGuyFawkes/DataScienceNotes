# %% [markdown]
# <a href="https://www.kaggle.com/code/akachimaduako/client-identities?scriptVersionId=103101136" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # By Maduako Akachi

# %% [markdown]
# # Introduction
#
# ## Dataset Description
# In this project, I will be analyzing a small dataset containing information about users from an online database.

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load and read the dataset into panda dataframe
#Read statistics
client_df = pd.read_csv('../input/client/ClientADIdentities.csv')
client_df.head()
# Out:
#      GivenName MiddleInitial    Surname           StreetAddress        City  \
# 0      Charles             D  Alexander     2088 Hillside Drive   Cambridge
# 1         John             J      Jones    1501 Copperhead Road  Farmington
# 2        Erika             N   Ransdell       174 Caldwell Road    Fairport
# 3        Frank             E    Helmick  3216 Harley Brook Lane        Erie
# 4  Christopher             C       Hale  2900 Golf Course Drive  Washington
#
#   State  ZipCode                        EmailAddress       Username  \
# 0    MA    12141  CharlesDAlexander@clientdomain.com       Othy1935
# 1    CT    16032         JohnJJones@clientdomain.com         Hustry
# 2    NY    14450     ErikaNRansdell@clientdomain.com  Chustered1993
# 3    PA    16501      FrankEHelmick@clientdomain.com       Auneance
# 4    VA    20011   ChristopherCHale@clientdomain.com        Fintich
#
#            Password TelephoneNumber
# 0       XDMSjLvWgGF    339-814-9960
# ...

# %%
#Get more information about the dataset
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GivenName        30 non-null     object
#  1   MiddleInitial    30 non-null     object
#  2   Surname          30 non-null     object
#  3   StreetAddress    30 non-null     object
#  4   City             30 non-null     object
#  5   State            30 non-null     object
#  6   ZipCode          30 non-null     int64
#  7   EmailAddress     30 non-null     object
#  8   Username         30 non-null     object
#  9   Password         30 non-null     object
#  10  TelephoneNumber  30 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 2.7+ KB

# %%
#Check for missing values
client_df.isnull().sum()
# Out:
# GivenName          0
# MiddleInitial      0
# Surname            0
# StreetAddress      0
# City               0
# State              0
# ZipCode            0
# EmailAddress       0
# Username           0
# Password           0
# TelephoneNumber    0
# dtype: int64

# %%
#Check for duplicate values
sum(client_df.duplicated())
# Out:
# 0

# %%
#Get value count of all state values
client_df['State'].value_counts()
# Out:
# CA    6
# IA    2
# VA    2
# NC    2
# FL    2
# TX    2
# MN    1
# AZ    1
# CO    1
# LA    1
# NE    1
# MA    1
# WI    1
# CT    1
# MI    1
# IN    1
# MD    1
# PA    1
# NY    1
# AK    1
# Name: State, dtype: int64

# %%
#Use pie chart to see distribution of state values
client_df['State'].value_counts().plot(kind='pie', figsize= (8,8));

# %%
##Use bar chart to see distribution of state values
client_df['State'].value_counts().plot(kind='bar', figsize= (8,8));
plt.title('distribution of clients according to state')
# Out:
# Text(0.5, 1.0, 'distribution of clients according to state')

# %% [markdown]
# This has already been cleaned
